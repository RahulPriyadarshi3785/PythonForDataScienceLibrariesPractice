# %%
#Importing libraries
#python library for numerical and scientific computing. pandas is built on top of numpy
import numpy as np 
#importing pandas
import pandas as pd

# %%
series = pd.Series(data = [78, 92, 36, 64, 89])  
series
# Out:
# 0    78
# 1    92
# 2    36
# 3    64
# 4    89
# dtype: int64

# %%
series.values
# Out:
# array([78, 92, 36, 64, 89], dtype=int64)

# %%
series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
series[1]
# Out:
# 92

# %%
series[1:3] # exclusive
# Out:
# 1    92
# 2    36
# dtype: int64

# %%
data = pd.Series(data = [700000, 800000, 1600000, 1800000, 30000000], index = ['Swift', 'Jazz', 'Civic', 'Altis', 'Gallardo'])
data
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
data['Swift']
# Out:
# 700000

# %%
data['Jazz': 'Gallardo']
# output starts from Jazz and goes till Gallardo(inclusive)
# Out:
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
#Using dictionary to create a series
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_price
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
#Creating a car price series with a dictionary
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
# Creating the car manufacturer series with a dictionary
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
print(car_price)
print(car_man)
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# dtype: object

# %%
cars = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
cars['Manufacturer']
# Out:
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# Name: Manufacturer, dtype: object

# %%
# A DataFrame is a collection of Series objects, and a single-column DataFrame can be constructed from a single Series:

#Using dictionary to create a series
car_price_dict = {'Swift':  700000,
                   'Jazz' :  800000,
                   'Civic' : 1600000,
                   'Altis' : 1800000,
                    'Gallardo': 30000000
                }
car_price = pd.Series(car_price_dict)
car_price
#Creating a DataFrame from car_price Series
pd.DataFrame(car_price, columns=['Car Price'])
# Out:
#           Car Price
# Swift        700000
# Jazz         800000
# Civic       1600000
# Altis       1800000
# Gallardo   30000000

# %%
###2. From a list of dictionaries
data = [{'Name': 'Subodh', 'Marks': 28},
        {'Name': 'Ram', 'Marks': 27}, 
        {'Name': 'Abdul', 'Marks': 26}, 
        {'Name': 'John', 'Marks': 28}]
pd.DataFrame(data)
# Out:
#      Name  Marks
# 0  Subodh     28
# 1     Ram     27
# 2   Abdul     26
# 3    John     28

# %%
pd.DataFrame([{'Subodh':20, 'Ram':25},
              {'Abdul':29, 'John':24}], 
              index = ['Mathematics', 'Physics'])
# Out:
#              Subodh   Ram  Abdul  John
# Mathematics    20.0  25.0    NaN   NaN
# Physics         NaN   NaN   29.0  24.0

# %%
#Using dictionary to create a series
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
cars = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
data_json = pd.read_json('C:\\Users\\hp\\Desktop\\Infy\\PythonForDataScienceCodeData\\example1626702607322.json',)
data_json.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print("""The axis keyword
One of the important parameters used while performing operations on DataFrames is 'axis'. Axis takes two values: 0 and 1.

axis = 0 represents row specific operations.

axis = 1 represents column specific operations""")
# Out:
# The axis keyword
# One of the important parameters used while performing operations on DataFrames is 'axis'. Axis takes two values: 0 and 1.
#
# axis = 0 represents row specific operations.
#
# axis = 1 represents column specific operations

# %%
df = pd.read_csv('C:\\Users\\hp\\Desktop\\Infy\\PythonForDataScienceCodeData\\auto_mpg.csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#displaying head
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#displaying tail
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
print('''Note: 

'inplace' makes changes to the original DataFrame.
df.fillna(condition) can be used to fill all the missing values. 
The missing values are filled with mean, median, mode, or constant values.

''')
df.dropna(inplace = True)
df.info()
# Out:
# Note:
#
# 'inplace' makes changes to the original DataFrame.
# df.fillna(condition) can be used to fill all the missing values.
# The missing values are filled with mean, median, mode, or constant values.
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
df['name']
# Output is a Series containing car names.
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 392, dtype: object

# %%
df[['name']]
# Output is a DataFrame containing just one column.
# Out:
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [392 rows x 1 columns]

# %%
df[['name', 'origin', 'model_year', 'mpg']]
# DataFrame
# Out:
#                           name  origin  model_year   mpg
# 0    chevrolet chevelle malibu     usa          70  18.0
# 1            buick skylark 320     usa          70  15.0
# 2           plymouth satellite     usa          70  18.0
# 3                amc rebel sst     usa          70  16.0
# 4                  ford torino     usa          70  17.0
# ..                         ...     ...         ...   ...
# 393            ford mustang gl     usa          82  27.0
# 394                  vw pickup  europe          82  44.0
# 395              dodge rampage     usa          82  32.0
# 396                ford ranger     usa          82  28.0
# 397                 chevy s-10     usa          82  31.0
#
# [392 rows x 4 columns]

# %%
### Setting custom index:
df_head = df.head()
#Setting name as custom index
df_head.set_index('name', inplace = True)
df_head
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %%
# 1.      iloc- Access a group of rows and columns by integer index.
df.iloc[2,1]
# Out:
# 8

# %%
df.iloc[2,-1]
# Out:
# 'plymouth satellite'

# %%
df.iloc[1:5, 4:6] # upper limit exclusive
# Out:
#    weight  acceleration
# 1    3693          11.5
# 2    3436          11.0
# 3    3433          12.0
# 4    3449          10.5

# %%
#2.      loc- Access a group of rows and columns by custom index.
#creating a subset using head. 'df' refers to XYZ Custom Cars DataFrame.
df_head = df.head()
#Setting name as custom index
df_head.set_index('name', inplace = True)
df_head.loc['buick skylark 320': 'amc rebel sst']
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0       165.0    3693
# plymouth satellite  18.0          8         318.0       150.0    3436
# amc rebel sst       16.0          8         304.0       150.0    3433
#
#                     acceleration  model_year origin
# name
# buick skylark 320           11.5          70    usa
# plymouth satellite          11.0          70    usa
# amc rebel sst               12.0          70    usa

# %%
#Subsetting from the full dataset
df.loc[0:5, ['cylinders', 'horsepower', 'name']] # upper limit inclusive
# Out:
#    cylinders  horsepower                       name
# 0          8       130.0  chevrolet chevelle malibu
# 1          8       165.0          buick skylark 320
# 2          8       150.0         plymouth satellite
# 3          8       150.0              amc rebel sst
# 4          8       140.0                ford torino
# 5          8       198.0           ford galaxie 500

# %%
# dicts can be used only for columns
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
# Adding columns to DataFrame
marks_df['Total'] = marks_df['Chemistry'] + marks_df['Physics'] + marks_df['Mathematics'] + marks_df['English']
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English  Total
# Subodh         67       45           50       19    181
# Ram            90       92           87       90    359
# Abdul          66       72           81       72    291
# John           32       40           12       68    152

# %%
# drop a column
marks_df.drop(columns = 'Total', inplace = True)
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
df.loc[df['model_year'] == 72 ].head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
#
#     model_year  origin                   name
# 57          72   japan  toyota corona hardtop
# 58          72     usa     dodge colt hardtop
# 59          72  europe      volkswagen type 3
# 60          72     usa         chevrolet vega
# 61          72     usa    ford pinto runabout

# %%
df.loc[(df['origin'] == 'japan') & (df['cylinders'] == 6)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 123  20.0          6         156.0       122.0    2807          13.5
# 210  19.0          6         156.0       108.0    2930          15.5
# 241  22.0          6         146.0        97.0    2815          14.5
# 333  32.7          6         168.0       132.0    2910          11.4
# 361  25.4          6         168.0       116.0    2900          12.6
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year origin               name
# 123          73  japan     toyota mark ii
# 210          76  japan     toyota mark ii
# 241          77  japan         datsun 810
# 333          80  japan      datsun 280-zx
# 361          81  japan    toyota cressida
# 362          81  japan  datsun 810 maxima

# %%
# Fuel efficient
# MPG > 29, Horsepower < 93.5,
# Weight < 2500
df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)].count()
# Out:
# mpg             81
# cylinders       81
# displacement    81
# horsepower      81
# weight          81
# acceleration    81
# model_year      81
# origin          81
# name            81
# dtype: int64

# %%
# Muscle cars
# Displacement >262, Horsepower > 126, Weight in range[2800, 3600]
df.loc[(df['displacement'] > 262) & (df['horsepower'] > 126) & (df['weight'] >=2800) & (df['weight'] <= 3600)].describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  11.000000       11.0     11.000000   11.000000    11.000000
# mean   16.681818        8.0    327.090909  151.545455  3385.363636
# std     2.262219        0.0     48.574591   26.845348   161.034948
# min    13.000000        8.0    302.000000  129.000000  3086.000000
# 25%    15.000000        8.0    302.000000  139.000000  3302.000000
# 50%    17.000000        8.0    305.000000  145.000000  3433.000000
# 75%    18.050000        8.0    318.000000  150.000000  3476.500000
# max    20.200000        8.0    455.000000  225.000000  3570.000000
#
#        acceleration  model_year
# count     11.000000   11.000000
# mean      11.427273   72.909091
# std        1.065918    3.645670
# min       10.000000   70.000000
# 25%       10.750000   70.000000
# 50%       11.200000   70.000000
# 75%       12.000000   76.500000
# max       13.200000   78.000000

# %%
# SUV
# Horsepower > 140 , Weight > 4500
df.loc[(df['horsepower'] > 140) & (df['weight'] >=4500)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 25 to 159
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           16 non-null     float64
#  1   cylinders     16 non-null     int64
#  2   displacement  16 non-null     float64
#  3   horsepower    16 non-null     float64
#  4   weight        16 non-null     int64
#  5   acceleration  16 non-null     float64
#  6   model_year    16 non-null     int64
#  7   origin        16 non-null     object
#  8   name          16 non-null     object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 1.2+ KB

# %%
# Racecar
# Weight <2223, acceleration > 17
df.loc[(df['acceleration'] > 17) & (df['weight'] < 2223)].tail(6)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 347  37.0          4          85.0        65.0    1975          19.4
# 348  37.7          4          89.0        62.0    2050          17.3
# 376  37.0          4          91.0        68.0    2025          18.2
# 377  31.0          4          91.0        68.0    1970          17.6
# 379  36.0          4          98.0        70.0    2125          17.3
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                name
# 347          81   japan      datsun 210 mpg
# 348          81   japan       toyota tercel
# 376          82   japan  mazda glc custom l
# 377          82   japan    mazda glc custom
# 379          82     usa      mercury lynx l
# 394          82  europe           vw pickup

# %%
# dicts can be used only for columns
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
# Making dataframe from list of list
mark = [[67,90,66,32], [45,92,72,40], [50,87,81,12], [19,90,72,68]]
mark_df = pd.DataFrame(mark, columns = ['Chemistry', 'Physics', 'Mathematics', 'English'], index = ['Subodh', 'Ram', 'Abdul', 'John'])
mark_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       90           66       32
# Ram            45       92           72       40
# Abdul          50       87           81       12
# John           19       90           72       68

# %%
## way 2 is to make row wise dictionary creation
marks = [{'Chemistry': 67, 'Physics': 45, 'Mathematics': 50, 'English' : 19},
        {'Chemistry': 90, 'Physics': 92, 'Mathematics': 87, 'English' : 90}, 
        {'Chemistry': 66, 'Physics': 72, 'Mathematics': 81, 'English' : 72}, 
        {'Chemistry': 32, 'Physics': 40, 'Mathematics': 12, 'English' : 68}]
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
print('''Syntax:

       DataFrame.mask(cond, other = nan, inplace = False, axis = None)

       cond – Where cond is False, keep the original value. Where True, replace with corresponding value from other

       other - Entries where cond is True are replaced with corresponding value from other.

       inplace - Whether to perform the operation in place on the data.

       axis – alignment axis''')
f = marks_df < 33
print(f)
# Out:
# Syntax:
#
#        DataFrame.mask(cond, other = nan, inplace = False, axis = None)
#
#        cond – Where cond is False, keep the original value. Where True, replace with corresponding value from other
#
#        other - Entries where cond is True are replaced with corresponding value from other.
#
#        inplace - Whether to perform the operation in place on the data.
#
#        axis – alignment axis
#         Chemistry  Physics  Mathematics  English
# Subodh      False    False        False     True
# Ram         False    False        False    False
# Abdul       False    False        False    False
# John         True    False         True    False

# %%
marks_df.mask(f, 'Fail')
# Out:
#        Chemistry  Physics Mathematics English
# Subodh        67       45          50    Fail
# Ram           90       92          87      90
# Abdul         66       72          81      72
# John        Fail       40        Fail      68

# %%
df.sort_values(by = 'cylinders, ascending=True, na_position='first')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 117  29.0          4          68.0        49.0    1867          19.5
# ..    ...        ...           ...         ...     ...           ...
# 94   13.0          8         440.0       215.0    4735          11.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 95   12.0          8         455.0       225.0    4951          11.0
#
#      model_year  origin                          name
# 71           72   japan               mazda rx2 coupe
# 111          73   japan                     maxda rx3
# 334          80   japan                 mazda rx-7 gs
# 243          77   japan                    mazda rx-4
# 117          73  europe                      fiat 128
# ..          ...     ...                           ...
# 94           73     usa  chrysler new yorker brougham
# 6            70     usa              chevrolet impala
# 8            70     usa              pontiac catalina
# 13           70     usa       buick estate wagon (sw)
# 95           73     usa      buick electra 225 custom
#
# [398 rows x 9 columns]

# %%
df.sort_values(by = ['cylinders', 'displacement'], ascending = (1,0))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 243  21.5          3          80.0       110.0    2720          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 271  23.2          4         156.0       105.0    2745          16.7
# ..    ...        ...           ...         ...     ...           ...
# 291  19.2          8         267.0       125.0    3605          15.0
# 165  20.0          8         262.0       110.0    3221          13.5
# 222  17.0          8         260.0       110.0    4060          19.0
# 249  19.9          8         260.0       110.0    3365          15.5
# 300  23.9          8         260.0        90.0    3420          22.2
#
#      model_year origin                               name
# 243          77  japan                         mazda rx-4
# 71           72  japan                    mazda rx2 coupe
# 111          73  japan                          maxda rx3
# 334          80  japan                      mazda rx-7 gs
# 271          78    usa                   plymouth sapporo
# ..          ...    ...                                ...
# 291          79    usa      chevrolet malibu classic (sw)
# 165          75    usa                chevrolet monza 2+2
# 222          77    usa         oldsmobile cutlass supreme
# 249          78    usa  oldsmobile cutlass salon brougham
# 300          79    usa  oldsmobile cutlass salon brougham
#
# [398 rows x 9 columns]

# %%
## encrpyting data to sine
encrypted_marks=np.sin(marks_df)
encrypted_marks
# Out:
#         Chemistry   Physics  Mathematics   English
# Subodh  -0.855520  0.850904    -0.262375  0.149877
# Ram      0.893997 -0.779466    -0.821818  0.893997
# Abdul   -0.026551  0.253823    -0.629888  0.253823
# John     0.551427  0.745113    -0.536573 -0.897928

# %%
encrypted_marks.reset_index(inplace = True)
encrypted_marks
# Out:
#     index  Chemistry   Physics  Mathematics   English
# 0  Subodh  -0.855520  0.850904    -0.262375  0.149877
# 1     Ram   0.893997 -0.779466    -0.821818  0.893997
# 2   Abdul  -0.026551  0.253823    -0.629888  0.253823
# 3    John   0.551427  0.745113    -0.536573 -0.897928

# %%
new_marks = marks_df + 5
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       50           55       24
# Ram            95       97           92       95
# Abdul          71       77           86       77
# John           37       45           17       73

# %%
new_marks = marks_df + [5,10,10,2]
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       55           60       21
# Ram            95      102           97       92
# Abdul          71       82           91       74
# John           37       50           22       70

# %%
print('''Apply: This method is used to apply a function along an axis of the DataFrame.

Syntax:

       DataFrame.apply(func, axis = 0, result_type = None)

       func : Function to apply to each column or row.

       axis: Axis along which the function is applied.

       result_type: one out of 'expand', 'reduce' or 'broadcast'. In the demo, 'broadcast' is used.

‘broadcast’ : results will be broadcast to the original shape of the DataFrame, the original index and columns will be retained.''')
# Out:
# Apply: This method is used to apply a function along an axis of the DataFrame.
#
# Syntax:
#
#        DataFrame.apply(func, axis = 0, result_type = None)
#
#        func : Function to apply to each column or row.
#
#        axis: Axis along which the function is applied.
#
#        result_type: one out of 'expand', 'reduce' or 'broadcast'. In the demo, 'broadcast' is used.
#
# ‘broadcast’ : results will be broadcast to the original shape of the DataFrame, the original index and columns will be retained.

# %%
#Creating the DataFrame
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['James', 'Lee', 'Anderson', 'John'])
marks_df
# Out:
#           Chemistry  Physics  Mathematics  English
# James            67       45           50       19
# Lee              90       92           87       90
# Anderson         66       72           81       72
# John             32       40           12       68

# %%
marks_df.apply(np.sum, axis = 0)
# Out:
# Chemistry      255
# Physics        249
# Mathematics    230
# English        249
# dtype: int64

# %%
marks_df.apply(np.sum, axis = 1)
# Out:
# James       181
# Lee         359
# Anderson    291
# John        152
# dtype: int64

# %%
marks_df.apply(func = np.mean, axis = 0, result_type = 'broadcast')
# marks by subject avg broadcast
# Out:
#           Chemistry  Physics  Mathematics  English
# James            63       62           57       62
# Lee              63       62           57       62
# Anderson         63       62           57       62
# John             63       62           57       62

# %%
marks_df.apply(func = np.mean, axis = 1, result_type = 'broadcast')
# marks by students avg broadcast
# Out:
#           Chemistry  Physics  Mathematics  English
# James            45       45           45       45
# Lee              89       89           89       89
# Anderson         72       72           72       72
# John             38       38           38       38

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
#Using list comprehension to get the numerical columns
list1 = [col for col in df.columns if df[col].dtype in ['float', 'int64']]
df[list1].agg(['min', 'max', 'mean'])
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min    9.000000   3.000000     68.000000   46.000000  1613.000000
# max   46.600000   8.000000    455.000000  230.000000  5140.000000
# mean  23.514573   5.454774    193.425879  104.469388  2970.424623
#
#       acceleration  model_year
# min        8.00000    70.00000
# max       24.80000    82.00000
# mean      15.56809    76.01005

# %%
df.groupby(['model_year']).count()
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          27      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          26      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          27      29            29
# 81           29         29            29          28      29            29
# 82           31         31            31          30      31            31
#
#             origin  name
# model_year
# 70              29    29
# 71              28    28
# 72              28    28
# 73              40    40
# 74              27    27
# 75              30    30
# 76              34    34
# 77              28    28
# 78              36    36
# 79              29    29
# 80              29    29
# 81              29    29
# 82              31    31

# %%
print('Combine DataFrame(concat):')
marks_A = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
          }
marks_A_df = pd.DataFrame(marks_A, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_B = {'Chemistry': [72,45,60,98], 
        'Physics': [78,34,72,95],  
          }
marks_B_df = pd.DataFrame(marks_B, index = ['Nandini', 'Zoya', 'Shivam', 'James'])
pd.concat([marks_A_df,marks_B_df], sort = False)
# Out:
# Combine DataFrame
#          Chemistry  Physics
# Subodh          67       45
# Ram             90       92
# Abdul           66       72
# John            32       40
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
df1 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'hire_date': [2004, 2008, 2012, 2014]})
display(df1,df2)
# Out:
#     employee        group
# 0      Jyoti   Accounting
# 1      Sapna  Engineering
# 2        Raj  Engineering
# 3  Ramaswamy           HR
#     employee  hire_date
# 0      Jyoti       2004
# 1      Sapna       2008
# 2        Raj       2012
# 3  Ramaswamy       2014

# %%
print('Null values due to cloumn mis match')
pd.concat([df1,df2], sort = False)
# Out:
# Null values due to cloumn mis match
#     employee        group  hire_date
# 0      Jyoti   Accounting        NaN
# 1      Sapna  Engineering        NaN
# 2        Raj  Engineering        NaN
# 3  Ramaswamy           HR        NaN
# 0      Jyoti          NaN     2004.0
# 1      Sapna          NaN     2008.0
# 2        Raj          NaN     2012.0
# 3  Ramaswamy          NaN     2014.0

# %%
print('''Merge : the merge function can be used which joins two tables based on a key. -> By default 'inner join'
Syntax:
       pd.merge(data1, data2, how = 'inner')''')
df3 = pd.merge(df1,df2)
df3
# Out:
# the merge function can be used which joins two tables based on a key.
# Syntax:
#        pd.merge(data1, data2, how = 'inner')
#     employee        group  hire_date
# 0      Jyoti   Accounting       2004
# 1      Sapna  Engineering       2008
# 2        Raj  Engineering       2012
# 3  Ramaswamy           HR       2014

# %%
df.groupby(['model_year']).count()[['mpg', 'cylinders']]
# Out:
#             mpg  cylinders
# model_year
# 70           29         29
# 71           28         28
# 72           28         28
# 73           40         40
# 74           27         27
# 75           30         30
# 76           34         34
# 77           28         28
# 78           36         36
# 79           29         29
# 80           29         29
# 81           29         29
# 82           31         31

# %%
df = pd.read_csv('C:\\Users\\hp\\Desktop\\Infy\\PythonForDataScienceCodeData\\auto_mpg.csv')
#Creating a DataFrame grouped on cylinders and model_year and finding mean, min and max of horsepower
grouped_multiple = df.groupby(['cylinders', 'model_year']).agg({'horsepower': ['mean', 'min', 'max']})
#Naming columns in grouped DataFrame
grouped_multiple.columns = ['hp_mean', 'hp_min', 'hp_max']
grouped_multiple
# Out:
#                          hp_mean  hp_min  hp_max
# cylinders model_year
# 3         72           97.000000    97.0    97.0
#           73           90.000000    90.0    90.0
#           77          110.000000   110.0   110.0
#           80          100.000000   100.0   100.0
# 4         70           87.714286    46.0   113.0
#           71           77.583333    60.0    95.0
#           72           85.142857    54.0   112.0
#           73           82.909091    46.0   112.0
#           74           74.000000    52.0    97.0
#           75           84.916667    53.0   115.0
#           76           75.600000    52.0   102.0
#           77           78.785714    58.0   110.0
#           78           79.705882    48.0   115.0
#           79           75.750000    65.0    90.0
#           80           74.043478    48.0   105.0
#           81           72.950000    58.0   100.0
#           82           79.148148    52.0    96.0
# 5         78          103.000000   103.0   103.0
#           79           77.000000    77.0    77.0
#           80           67.000000    67.0    67.0
# 6         70           91.750000    85.0    97.0
#           71           98.875000    88.0   110.0
#           73          102.125000    88.0   122.0
#           74          101.666667    95.0   110.0
#           75           96.750000    72.0   110.0
#           76           98.700000    78.0   120.0
#           77          102.000000    97.0   110.0
#           78          109.833333    85.0   165.0
#           79          105.000000    85.0   115.0
#           80          111.000000    90.0   132.0
#           81          100.714286    76.0   120.0
#           82          102.333333    85.0   112.0
# 8         70          183.666667   130.0   225.0
#           71          166.857143   150.0   180.0
#           72          159.692308   130.0   208.0
#           73          170.000000   137.0   230.0
#           74          146.000000   140.0   150.0
#           75          142.000000   110.0   170.0
#           76          146.333333   120.0   180.0
#           77          152.375000   110.0   190.0
#           78          135.500000   110.0   145.0
#           79          131.900000    90.0   155.0
#           81          105.000000   105.0   105.0

# %%
#Resetting index
grouped_multiple = grouped_multiple.reset_index()
#Viewing head of resulting DataFrame
grouped_multiple.head()
# Out:
#    cylinders  model_year     hp_mean  hp_min  hp_max
# 0          3          72   97.000000    97.0    97.0
# 1          3          73   90.000000    90.0    90.0
# 2          3          77  110.000000   110.0   110.0
# 3          3          80  100.000000   100.0   100.0
# 4          4          70   87.714286    46.0   113.0

# %%
df.groupby(['model_year']).mean().sort_values('acceleration', ascending = False)[['acceleration']]
# relationship between model year and acceleration of cars.
# Out:
#             acceleration
# model_year
# 80             16.934483
# 82             16.638710
# 81             16.306897
# 74             16.203704
# 75             16.050000
# 76             15.941176
# 79             15.813793
# 78             15.805556
# 77             15.435714
# 71             15.142857
# 72             15.125000
# 73             14.312500
# 70             12.948276

# %%
print('Append DataFrame:')
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
print(df)
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
print(df.append(df2))
# Out:
#    A  B
# x  1  2
# y  3  4
#    A  B
# x  1  2
# y  3  4
# x  5  6
# y  7  8

# %%
df.append(df2, ignore_index=True)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
print('frequency distribution of different number of cylinders across different years.')
pd.crosstab(df['model_year'], df['cylinders'])
# Out:
# frequency distribution of different number of cylinders across different years.
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0

# %%
print('''the mean of all the numerical attributes of cars for each year
Syntax :
       pd.pivot_table(data, index, aggfunc)

      data: DataFrame

       index: column to be set as index

       aggfunc: function/list of functions, default = numpy.mean''')
pivot1 = pd.pivot_table(df, index = 'model_year', aggfunc=np.mean)
pivot1
# Out:
# the mean of all the numerical attributes of cars for each year
# Syntax :
#        pd.pivot_table(data, index, aggfunc)
#
#       data: DataFrame
#
#        index: column to be set as index
#
#        aggfunc: function/list of functions, default = numpy.mean
#             acceleration  cylinders  displacement  horsepower        mpg  \
# model_year
# 70             12.948276   6.758621    281.413793  147.827586  17.689655
# 71             15.142857   5.571429    209.750000  107.037037  21.250000
# 72             15.125000   5.821429    218.375000  120.178571  18.714286
# 73             14.312500   6.375000    256.875000  130.475000  17.100000
# 74             16.203704   5.259259    171.740741   94.230769  22.703704
# 75             16.050000   5.600000    205.533333  101.066667  20.266667
# 76             15.941176   5.647059    197.794118  101.117647  21.573529
# 77             15.435714   5.464286    191.392857  105.071429  23.375000
# 78             15.805556   5.361111    177.805556   99.694444  24.061111
# 79             15.813793   5.827586    206.689655  101.206897  25.093103
# 80             16.934483   4.137931    115.827586   77.481481  33.696552
# 81             16.306897   4.620690    135.310345   81.035714  30.334483
# 82             16.638710   4.193548    128.870968   81.466667  31.709677
#
#                  weight
# model_year
# 70          3372.793103
# 71          2995.428571
# 72          3237.714286
# 73          3419.025000
# 74          2877.925926
# 75          3176.800000
# 76          3078.735294
# 77          2997.357143
# 78          2861.805556
# 79          3055.344828
# 80          2436.655172
# 81          2522.931034
# 82          2453.548387

# %%
print('Pandas Scatter plot:')
df.plot(x = 'model_year', y = 'acceleration', marker = 'o', kind = 'scatter');
# Out:
# Pandas Scatter plot:

# %%
print('Pandas Box plot:')
df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');
# Out:
# Pandas Box plot:

# %%
print('Pandas Histogram:')
df['cylinders'].plot(kind = 'hist')
# Out:
# Pandas Histogram:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('the relationship between weight and mpg')
df.plot(x = 'weight', y = 'mpg', kind = 'scatter')
# Out:
# the relationship between weight and mpg
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
print('sorted mean values of acceleration with respect to number of cylinders')
df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind = 'bar')
# Out:
# sorted mean values of acceleration with respect to number of cylinders
# <AxesSubplot:xlabel='cylinders'>

# %%
# Out:
# Index(['Employee_Id', 'Count'], dtype='object')
