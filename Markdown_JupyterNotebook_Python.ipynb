# %% [markdown]
# # Hi

# %% [markdown]
# ## Header2

# %% [markdown]
# ###### Header6

# %% [markdown]
# > Blockquotes

# %% [markdown]
# <a id = "division_ID">Scroll here from Section title(internal link)</a>

# %% [markdown]
# `str = "This is block level code"
# print(str)`

# %% [markdown]
# $ sqrt(5*x) $

# %%
print('maths formula')
# Out:
# maths formula

# %% [markdown]
# The line breaks after using <br> br tags and it is awesome.

# %% [markdown]
# <b>This is bold text </b>

# %% [markdown]
# <i>This is italic text</i>

# %% [markdown]
# ---

# %%
print('horizontal line')
# Out:
# horizontal line

# %% [markdown]
# <ol>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ol>

# %% [markdown]
# <ul>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ul>

# %% [markdown]
# ---

# %% [markdown]
# - x
# - y
# - z

# %% [markdown]
# [Section title](#division_ID)

# %% [markdown]
# __[Markdown tutorials(External Link Example)](https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook)__

# %% [markdown]
# ![profile%20picture.jpg](attachment:profile%20picture.jpg)

# %% [markdown]
# ![sggzys0.png](attachment:sggzys0.png)

# %% [markdown]
# <img src="https://i.imgur.com/rr9YIOR.png" width ="500" height=500 >

# %% [markdown]
# <b>check the markup tag above</b>
